# %% [markdown]
# # Assignment 4: Day4

# %% [raw]
# Questions 1:
# How to import pandas and check the version?

# %%
# importing the pandas library by its alias name 
import pandas as pd

# %%
# checking the version of pandas 
print(pd.__version__)      #getting the version number of pandas

#getting the detailed version of pandas 
pd.show_versions()
# Out:
# 0.25.1
#
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.4.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# machine          : AMD64
# processor        : Intel64 Family 6 Model 58 Stepping 9, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : None.None
#
# pandas           : 0.25.1
# numpy            : 1.16.5
# pytz             : 2019.3
# dateutil         : 2.8.0
# pip              : 19.2.3
# setuptools       : 41.4.0
# Cython           : 0.29.13
# pytest           : 5.2.1
# hypothesis       : None
# sphinx           : 2.2.0
# blosc            : None
# feather          : None
# xlsxwriter       : 1.2.1
# lxml.etree       : 4.4.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : 2.8.4 (dt dec pq3 ext lo64)
# jinja2           : 2.10.3
# IPython          : 7.8.0
# pandas_datareader: None
# bs4              : 4.8.0
# ...

# %% [raw]
# Questions 2:
# How to create a series from a numpy array?

# %%
#importing the numpy and pandas
import numpy as np
import pandas as pd
a=np.array([10,15,20,14,16,18,19,25,24,26,29,30])
s=pd.Series(a)
print(s)
# Out:
# 0     10
# 1     15
# 2     20
# 3     14
# 4     16
# 5     18
# 6     19
# 7     25
# 8     24
# 9     26
# 10    29
# 11    30
# dtype: int32

# %% [raw]
# Questions 3:
# How to convert the index of a series into a column of a dataframe?

# %%
s = pd.Series([10,15,20,14,16,18,19,25,24,26,29,30], name='Numbers_Series',
              index=pd.Index(['A', 'B', 'C', 'D','E','F','G','H','I','J','K','L'], name='index'))
print(s)
# Out:
# index
# A    10
# B    15
# C    20
# D    14
# E    16
# F    18
# G    19
# H    25
# I    24
# J    26
# K    29
# L    30
# Name: Numbers_Series, dtype: int64

# %% [raw]
# Questions 4:
# Write the code to list all the datasets available in seaborn library.
# Load the 'mpg' dataset
# Note: mpg dataset will be read from seaborn module in the manner sir has already shown(provided in the
# materials folder)

# %%
#importing the needed library
import pandas as pd 
import seaborn as sns 
df = sns.load_dataset('mpg')
#print df.head()

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [raw]
# Questions 5:
# Which country origin cars are a part of this dataset?

# %%
print(df["origin"])
# Out:
# 0         usa
# 1         usa
# 2         usa
# 3         usa
# 4         usa
#         ...
# 393       usa
# 394    europe
# 395       usa
# 396       usa
# 397       usa
# Name: origin, Length: 398, dtype: object

# %%
#unique country
df.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %% [raw]
# Questions 6:
# Extract the part of the dataframe which contains cars belonging to 'usa'

# %%
df1 =df[df['origin'].str.contains("usa")]

# %%
df1
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# ...
